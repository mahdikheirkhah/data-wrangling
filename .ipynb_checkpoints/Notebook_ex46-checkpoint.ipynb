# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Let's assume we trained a machine learning model that predicts a daily score on the companies (tickers) below. It may be very useful to unstack the MultiIndex: plot the time series, vectorize the backtest, ...
#
# ```python
# business_dates = pd.bdate_range('2021-01-01', '2021-12-31')
#
# # generate tickers
# tickers = ['AAPL', 'FB', 'GE', 'AMZN', 'DAI']
#
# # create indexes
# index = pd.MultiIndex.from_product([business_dates, tickers], names=['Date', 'Ticker'])
#
# # create DFs
# market_data = pd.DataFrame(index=index,
#                         data=np.random.randn(len(index), 1),
#                         columns=['Prediction'])
#
# ```

# %%
business_dates = pd.bdate_range('2021-01-01', '2021-12-31')

# generate tickers
tickers = ['AAPL', 'FB', 'GE', 'AMZN', 'DAI']

# create indexes
index = pd.MultiIndex.from_product([business_dates, tickers], names=['Date', 'Ticker'])

# create DFs
market_data = pd.DataFrame(index=index,
                        data=np.random.randn(len(index), 1),
                        columns=['Prediction'])
market_data
# Out:
#                    Prediction
# Date       Ticker
# 2021-01-01 AAPL      1.952452
#            FB        0.806679
#            GE        0.833985
#            AMZN      0.719542
#            DAI       1.262945
# ...                       ...
# 2021-12-31 AAPL     -0.410712
#            FB       -1.328878
#            GE       -1.677548
#            AMZN     -0.176483
#            DAI      -0.927372
#
# [1305 rows x 1 columns]

# %% [markdown]
# 1. Unstack the DataFrame.
#
# The first 3 rows of the DataFrame should look like this:
#
# | Date                | ('Prediction', 'AAPL') | ('Prediction', 'AMZN') | ('Prediction', 'DAI') | ('Prediction', 'FB') | ('Prediction', 'GE') |
# | :------------------ | ---------------------: | ---------------------: | --------------------: | -------------------: | -------------------: |
# | 2021-01-01 00:00:00 |               0.382312 |              -0.072392 |             -0.551167 |           -0.0585555 |              1.05955 |
# | 2021-01-04 00:00:00 |              -0.560953 |               0.503199 |              -0.79517 |             -3.23136 |              1.50271 |
# | 2021-01-05 00:00:00 |               0.211489 |                1.84867 |              0.287906 |             -1.81119 |              1.20321 |

# %%
unstacked = market_data.unstack(level=-1)
unstacked.columns = [str(col) for col in unstacked.columns]

unstacked.columns.name = None

unstacked.head(3)
# Out:
#             ('Prediction', 'AAPL')  ('Prediction', 'AMZN')  \
# Date
# 2021-01-01                1.952452                0.719542
# 2021-01-04                1.019924               -0.568430
# 2021-01-05               -1.270995               -0.348300
#
#             ('Prediction', 'DAI')  ('Prediction', 'FB')  ('Prediction', 'GE')
# Date
# 2021-01-01               1.262945              0.806679              0.833985
# 2021-01-04               0.223104             -0.777678             -0.376063
# 2021-01-05              -0.190742              1.075246             -0.629804

# %% [markdown]
# 2. Plot the 5 times series in the same plot using Pandas built-in visualization functions with a title.

# %%
# unstacked.plot(
#     title='Daily Prediction Scores by Ticker', 
#     figsize=(12, 8),
#     grid=True,  
#     xlabel='Date',   
#     ylabel='Score',
#     legend = True
# ) 
plot_df = market_data.unstack(level=-1)
plot_df.columns = [col[1] for col in plot_df.columns]

plot_df.plot(
    title='Daily Prediction Scores by Ticker', 
    figsize=(12, 8),
    grid=True,      
    xlabel='Date', 
    ylabel='Prediction'
)
# Out:
# <Axes: title={'center': 'Daily Prediction Scores by Ticker'}, xlabel='Date', ylabel='Score'>
